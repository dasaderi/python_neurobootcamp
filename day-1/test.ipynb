# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.signal as ss
from __future__ import absolute_import, division, print_function

# %%
data_m = np.random.rand(100,10)

# %%
data_m
# Out:
# array([[  1.71411666e-01,   7.20104206e-01,   3.64257884e-01,
#           8.82096476e-01,   6.53720227e-02,   6.80444545e-02,
#           7.50996694e-01,   4.70146296e-01,   8.84360388e-01,
#           7.24256675e-01],
#        [  7.33594694e-01,   4.97997783e-01,   5.72569738e-01,
#           2.29219213e-01,   3.17406304e-01,   9.51017251e-01,
#           5.64590642e-01,   1.42101177e-02,   5.45587359e-01,
#           6.49584351e-01],
#        [  4.17467002e-01,   9.28651354e-01,   4.73020846e-01,
#           4.97645877e-02,   8.17810811e-01,   1.16471154e-01,
#           3.25977930e-01,   8.63801647e-01,   1.39907310e-01,
#           2.66222727e-01],
#        [  6.37335759e-01,   3.10030139e-01,   1.42646722e-01,
#           5.32577424e-01,   9.19369522e-01,   9.27792185e-01,
#           7.86238787e-01,   1.95067053e-01,   3.19598217e-01,
#           4.97712910e-01],
#        [  6.37804639e-01,   3.57299394e-01,   6.94979086e-01,
# ...

# %%
# Compute the mean over the 10 columns and print this array of 10 values
np.mean(data_m, axis=0)
# Out:
# array([ 0.50733857,  0.47084979,  0.53168837,  0.53167075,  0.53599768,
#         0.5220051 ,  0.4880716 ,  0.45498213,  0.51096932,  0.50323304])

# %%
np.mean(data_m)
# Out:
# 0.50568063613947567

# %%
import os

path = "data/maze_data/"
file_list = os.listdir(path)
file_list
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-5a565cee49cb> in <module>()
#       2
#       3 path = "data/maze_data/"
# ----> 4 file_list = os.listdir(path)
#       5 file_list
#
# OSError: [Errno 2] No such file or directory: 'data/maze_data/'

# %%
mouse_list = []

# %%
os.getcwd()
# Out:
# '/Users/Lucifer/Desktop/python_neurobootcamp/day-1'

# %%
meta = pd.read_csv("meta_data_PV_3_10_03_2014.csv", index_col=0)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-16-582ca1879c5b> in <module>()
# ----> 1 meta = pd.read_csv("meta_data_PV_3_10_03_2014.csv", index_col=0)
#
# ...
